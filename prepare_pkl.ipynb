# %%
import os
from os.path import join
from matplotlib import pyplot as plt
import pickle
import numpy as np

# %%
partner_dir = r'/local/scratch-2/gp518/preprocessed_data/PARTNER'
imgs_names = os.listdir(join(partner_dir, 'images'))
lbls_names = os.listdir(join(partner_dir, 'labels'))
subject_ids = sorted(list(set([i.split('-')[0] for i in imgs_names])))
subject_ids[:10]
# Out:
# ['1002',
#  '1003',
#  '1004',
#  '1006',
#  '1008',
#  '1011',
#  '1015',
#  '1016',
#  '1019',
#  '1020']

# %%
_dict = {}
for subject_id in subject_ids:
    _dict[subject_id] = {
        'horizontal_flip': 'NO', 
        'cancer_label': {
            'benign': 0,
            'right_benign': 0,
            'malignant': 0,
            'left_benign': 0,
            'unknown': 0,
            'right_malignant': 0,
            'left_malignant': 0
            }
        }

    for laterality, laterality_long in {'L': 'left', 'R': 'right'}.items():
        has_label_filename = None
        for view in ['CC', 'MLO']:
            filename = f'{subject_id}-{laterality}-{view}.png'
            if filename not in imgs_names:
                continue
            _dict[subject_id][f'{laterality}-{view}'] = [filename[:-len('.png')]]
            if filename in lbls_names:
                np_array = np.array(plt.imread(join(partner_dir, 'labels', filename)))
                N = np_array.sum()
                # print(filename, N)
                if N > 0:
                    _dict[subject_id][f'{laterality}-{view}_malignant_seg'] = [filename[:-len('.png')]]
                    has_label_filename = filename

        if has_label_filename is not None:
            _dict[subject_id]['cancer_label']['malignant'] += 1
            _dict[subject_id]['cancer_label'][f'{laterality_long}_malignant'] += 1
_dict
# Out:
# {'1002': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1002-L-CC'],
#   'L-MLO': ['1002-L-MLO'],
#   'R-CC': ['1002-R-CC'],
#   'R-CC_malignant_seg': ['1002-R-CC'],
#   'R-MLO': ['1002-R-MLO'],
#   'R-MLO_malignant_seg': ['1002-R-MLO']},
#  '1003': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1003-L-CC'],
#   'L-MLO': ['1003-L-MLO'],
#   'L-MLO_malignant_seg': ['1003-L-MLO'],
#   'R-CC': ['1003-R-CC'],
#   'R-MLO': ['1003-R-MLO']},
#  '1004': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1004-L-CC'],
#   'L-CC_malignant_seg': ['1004-L-CC'],
#   'L-MLO': ['1004-L-MLO'],
#   'L-MLO_malignant_seg': ['1004-L-MLO'],
#   'R-CC': ['1004-R-CC'],
#   'R-MLO': ['1004-R-MLO']},
#  '1006': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1006-L-CC'],
#   'L-CC_malignant_seg': ['1006-L-CC'],
#   'L-MLO': ['1006-L-MLO'],
#   'L-MLO_malignant_seg': ['1006-L-MLO'],
#   'R-CC': ['1006-R-CC'],
#   'R-MLO': ['1006-R-MLO']},
#  '1008': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1008-L-CC'],
#   'L-CC_malignant_seg': ['1008-L-CC'],
#   'L-MLO': ['1008-L-MLO'],
#   'L-MLO_malignant_seg': ['1008-L-MLO'],
#   'R-CC': ['1008-R-CC'],
#   'R-MLO': ['1008-R-MLO']},
#  '1011': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1011-L-CC'],
#   'L-CC_malignant_seg': ['1011-L-CC'],
#   'L-MLO': ['1011-L-MLO'],
#   'L-MLO_malignant_seg': ['1011-L-MLO'],
#   'R-CC': ['1011-R-CC'],
#   'R-MLO': ['1011-R-MLO']},
#  '1015': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1015-L-CC'],
#   'L-CC_malignant_seg': ['1015-L-CC'],
#   'L-MLO': ['1015-L-MLO'],
#   'L-MLO_malignant_seg': ['1015-L-MLO'],
#   'R-CC': ['1015-R-CC'],
#   'R-MLO': ['1015-R-MLO']},
#  '1016': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1016-L-CC'],
#   'L-MLO': ['1016-L-MLO'],
#   'R-CC': ['1016-R-CC'],
#   'R-CC_malignant_seg': ['1016-R-CC'],
#   'R-MLO': ['1016-R-MLO'],
#   'R-MLO_malignant_seg': ['1016-R-MLO']},
#  '1019': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1019-L-CC'],
#   'L-MLO': ['1019-L-MLO'],
#   'R-CC': ['1019-R-CC'],
#   'R-CC_malignant_seg': ['1019-R-CC'],
#   'R-MLO': ['1019-R-MLO'],
#   'R-MLO_malignant_seg': ['1019-R-MLO']},
#  '1020': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1020-L-CC'],
#   'L-MLO': ['1020-L-MLO'],
#   'R-CC': ['1020-R-CC'],
#   'R-CC_malignant_seg': ['1020-R-CC'],
#   'R-MLO': ['1020-R-MLO'],
#   'R-MLO_malignant_seg': ['1020-R-MLO']},
#  '1021': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1021-L-CC'],
#   'L-CC_malignant_seg': ['1021-L-CC'],
#   'L-MLO': ['1021-L-MLO'],
#   'L-MLO_malignant_seg': ['1021-L-MLO'],
#   'R-CC': ['1021-R-CC'],
#   'R-MLO': ['1021-R-MLO']},
#  '1022': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1022-L-CC'],
#   'L-CC_malignant_seg': ['1022-L-CC'],
#   'L-MLO': ['1022-L-MLO'],
#   'L-MLO_malignant_seg': ['1022-L-MLO'],
#   'R-CC': ['1022-R-CC'],
#   'R-MLO': ['1022-R-MLO']},
#  '1024': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1024-L-CC'],
#   'L-MLO': ['1024-L-MLO'],
#   'R-CC': ['1024-R-CC'],
#   'R-CC_malignant_seg': ['1024-R-CC'],
#   'R-MLO': ['1024-R-MLO'],
#   'R-MLO_malignant_seg': ['1024-R-MLO']},
#  '1044': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1044-L-CC'],
#   'L-CC_malignant_seg': ['1044-L-CC'],
#   'L-MLO': ['1044-L-MLO'],
#   'L-MLO_malignant_seg': ['1044-L-MLO'],
#   'R-CC': ['1044-R-CC'],
#   'R-MLO': ['1044-R-MLO']},
#  '1045': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1045-L-CC'],
#   'L-CC_malignant_seg': ['1045-L-CC'],
#   'L-MLO': ['1045-L-MLO'],
#   'L-MLO_malignant_seg': ['1045-L-MLO'],
#   'R-CC': ['1045-R-CC'],
#   'R-MLO': ['1045-R-MLO']},
#  '1046': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1046-L-CC'],
#   'L-MLO': ['1046-L-MLO'],
#   'R-CC': ['1046-R-CC'],
#   'R-MLO': ['1046-R-MLO']},
#  '1051': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'R-CC': ['1051-R-CC'],
#   'R-CC_malignant_seg': ['1051-R-CC'],
#   'R-MLO': ['1051-R-MLO'],
#   'R-MLO_malignant_seg': ['1051-R-MLO']},
#  '1052': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1052-L-CC'],
#   'L-MLO': ['1052-L-MLO'],
#   'R-CC': ['1052-R-CC'],
#   'R-CC_malignant_seg': ['1052-R-CC'],
#   'R-MLO': ['1052-R-MLO'],
#   'R-MLO_malignant_seg': ['1052-R-MLO']},
#  '1057': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1057-L-CC'],
#   'L-MLO': ['1057-L-MLO'],
#   'R-CC': ['1057-R-CC'],
#   'R-CC_malignant_seg': ['1057-R-CC'],
#   'R-MLO': ['1057-R-MLO']},
#  '1059': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1059-L-CC'],
#   'L-MLO': ['1059-L-MLO'],
#   'R-CC': ['1059-R-CC'],
#   'R-MLO': ['1059-R-MLO']},
#  '1064': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1064-L-CC'],
#   'L-CC_malignant_seg': ['1064-L-CC'],
#   'L-MLO': ['1064-L-MLO'],
#   'L-MLO_malignant_seg': ['1064-L-MLO'],
#   'R-CC': ['1064-R-CC'],
#   'R-MLO': ['1064-R-MLO']},
#  '1067': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1067-L-CC'],
#   'L-MLO': ['1067-L-MLO'],
#   'L-MLO_malignant_seg': ['1067-L-MLO'],
#   'R-CC': ['1067-R-CC'],
#   'R-MLO': ['1067-R-MLO']},
#  '1076': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1076-L-CC'],
#   'L-CC_malignant_seg': ['1076-L-CC'],
#   'L-MLO': ['1076-L-MLO'],
#   'L-MLO_malignant_seg': ['1076-L-MLO'],
#   'R-CC': ['1076-R-CC'],
#   'R-MLO': ['1076-R-MLO']},
#  '1079': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1079-L-CC'],
#   'L-CC_malignant_seg': ['1079-L-CC'],
#   'L-MLO': ['1079-L-MLO'],
#   'L-MLO_malignant_seg': ['1079-L-MLO'],
#   'R-CC': ['1079-R-CC'],
#   'R-MLO': ['1079-R-MLO']},
#  '1084': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1084-L-CC'],
#   'L-CC_malignant_seg': ['1084-L-CC'],
#   'L-MLO': ['1084-L-MLO'],
#   'L-MLO_malignant_seg': ['1084-L-MLO'],
#   'R-CC': ['1084-R-CC'],
#   'R-MLO': ['1084-R-MLO']},
#  '1091': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1091-L-CC'],
#   'L-CC_malignant_seg': ['1091-L-CC'],
#   'L-MLO': ['1091-L-MLO'],
#   'L-MLO_malignant_seg': ['1091-L-MLO'],
#   'R-CC': ['1091-R-CC'],
#   'R-MLO': ['1091-R-MLO']},
#  '1092': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1092-L-CC'],
#   'L-CC_malignant_seg': ['1092-L-CC'],
#   'L-MLO': ['1092-L-MLO'],
#   'L-MLO_malignant_seg': ['1092-L-MLO'],
#   'R-CC': ['1092-R-CC'],
#   'R-MLO': ['1092-R-MLO']},
#  '1093': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1093-L-CC'],
#   'L-MLO': ['1093-L-MLO'],
#   'R-CC': ['1093-R-CC'],
#   'R-CC_malignant_seg': ['1093-R-CC'],
#   'R-MLO': ['1093-R-MLO'],
#   'R-MLO_malignant_seg': ['1093-R-MLO']},
#  '1096': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1096-L-CC'],
#   'L-CC_malignant_seg': ['1096-L-CC'],
#   'L-MLO': ['1096-L-MLO'],
#   'L-MLO_malignant_seg': ['1096-L-MLO'],
#   'R-CC': ['1096-R-CC'],
#   'R-MLO': ['1096-R-MLO']},
#  '1103': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1103-L-CC'],
#   'L-MLO': ['1103-L-MLO'],
#   'R-CC': ['1103-R-CC'],
#   'R-MLO': ['1103-R-MLO']},
#  '1117': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1117-L-CC'],
#   'L-CC_malignant_seg': ['1117-L-CC'],
#   'L-MLO': ['1117-L-MLO'],
#   'L-MLO_malignant_seg': ['1117-L-MLO'],
#   'R-CC': ['1117-R-CC'],
#   'R-MLO': ['1117-R-MLO']},
#  '1123': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1123-L-CC'],
#   'L-CC_malignant_seg': ['1123-L-CC'],
#   'L-MLO': ['1123-L-MLO'],
#   'L-MLO_malignant_seg': ['1123-L-MLO'],
#   'R-CC': ['1123-R-CC'],
#   'R-MLO': ['1123-R-MLO']},
#  '1133': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1133-L-CC'],
#   'L-CC_malignant_seg': ['1133-L-CC'],
#   'L-MLO': ['1133-L-MLO'],
#   'L-MLO_malignant_seg': ['1133-L-MLO'],
#   'R-CC': ['1133-R-CC'],
#   'R-MLO': ['1133-R-MLO']},
#  '1135': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1135-L-CC'],
#   'L-CC_malignant_seg': ['1135-L-CC'],
#   'L-MLO': ['1135-L-MLO'],
#   'L-MLO_malignant_seg': ['1135-L-MLO'],
#   'R-CC': ['1135-R-CC'],
#   'R-MLO': ['1135-R-MLO']},
#  '1137': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1137-L-CC'],
#   'L-MLO': ['1137-L-MLO'],
#   'R-CC': ['1137-R-CC'],
#   'R-MLO': ['1137-R-MLO'],
#   'R-MLO_malignant_seg': ['1137-R-MLO']},
#  '1141': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1141-L-CC'],
#   'L-MLO': ['1141-L-MLO'],
#   'R-CC': ['1141-R-CC'],
#   'R-CC_malignant_seg': ['1141-R-CC'],
#   'R-MLO': ['1141-R-MLO'],
#   'R-MLO_malignant_seg': ['1141-R-MLO']},
#  '1145': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1145-L-CC'],
#   'L-MLO': ['1145-L-MLO'],
#   'R-CC': ['1145-R-CC'],
#   'R-MLO': ['1145-R-MLO']},
#  '1150': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1150-L-CC'],
#   'L-MLO': ['1150-L-MLO'],
#   'R-CC': ['1150-R-CC'],
#   'R-MLO': ['1150-R-MLO'],
#   'R-MLO_malignant_seg': ['1150-R-MLO']},
#  '1151': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1151-L-CC'],
#   'L-MLO': ['1151-L-MLO'],
#   'R-CC': ['1151-R-CC'],
#   'R-CC_malignant_seg': ['1151-R-CC'],
#   'R-MLO': ['1151-R-MLO'],
#   'R-MLO_malignant_seg': ['1151-R-MLO']},
#  '1152': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1152-L-CC'],
#   'L-MLO': ['1152-L-MLO'],
#   'R-CC': ['1152-R-CC'],
#   'R-CC_malignant_seg': ['1152-R-CC'],
#   'R-MLO': ['1152-R-MLO'],
#   'R-MLO_malignant_seg': ['1152-R-MLO']},
#  '1153': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1153-L-CC'],
#   'L-CC_malignant_seg': ['1153-L-CC'],
#   'L-MLO': ['1153-L-MLO'],
#   'L-MLO_malignant_seg': ['1153-L-MLO'],
#   'R-CC': ['1153-R-CC'],
#   'R-MLO': ['1153-R-MLO']},
#  '1154': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1154-L-CC'],
#   'L-MLO': ['1154-L-MLO'],
#   'R-CC': ['1154-R-CC'],
#   'R-CC_malignant_seg': ['1154-R-CC'],
#   'R-MLO': ['1154-R-MLO'],
#   'R-MLO_malignant_seg': ['1154-R-MLO']},
#  '1158': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1158-L-CC'],
#   'L-CC_malignant_seg': ['1158-L-CC'],
#   'L-MLO': ['1158-L-MLO'],
#   'L-MLO_malignant_seg': ['1158-L-MLO'],
#   'R-CC': ['1158-R-CC']},
#  '1163': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1163-L-CC'],
#   'L-MLO': ['1163-L-MLO'],
#   'R-CC': ['1163-R-CC'],
#   'R-MLO': ['1163-R-MLO'],
#   'R-MLO_malignant_seg': ['1163-R-MLO']},
#  '1165': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-MLO': ['1165-L-MLO'],
#   'L-MLO_malignant_seg': ['1165-L-MLO'],
#   'R-CC': ['1165-R-CC'],
#   'R-MLO': ['1165-R-MLO']},
#  '1179': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1179-L-CC'],
#   'L-CC_malignant_seg': ['1179-L-CC'],
#   'L-MLO': ['1179-L-MLO'],
#   'L-MLO_malignant_seg': ['1179-L-MLO'],
#   'R-CC': ['1179-R-CC'],
#   'R-MLO': ['1179-R-MLO']},
#  '1181': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1181-L-CC'],
#   'L-MLO': ['1181-L-MLO'],
#   'R-CC': ['1181-R-CC'],
#   'R-CC_malignant_seg': ['1181-R-CC'],
#   'R-MLO': ['1181-R-MLO'],
#   'R-MLO_malignant_seg': ['1181-R-MLO']},
#  '1183': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1183-L-CC'],
#   'L-MLO': ['1183-L-MLO'],
#   'R-CC': ['1183-R-CC'],
#   'R-CC_malignant_seg': ['1183-R-CC'],
#   'R-MLO': ['1183-R-MLO']},
#  '1191': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1191-L-CC'],
#   'L-MLO': ['1191-L-MLO'],
#   'R-CC': ['1191-R-CC'],
#   'R-CC_malignant_seg': ['1191-R-CC'],
#   'R-MLO': ['1191-R-MLO'],
#   'R-MLO_malignant_seg': ['1191-R-MLO']},
#  '1192': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1192-L-CC'],
#   'L-MLO': ['1192-L-MLO'],
#   'R-CC': ['1192-R-CC'],
#   'R-CC_malignant_seg': ['1192-R-CC'],
#   'R-MLO': ['1192-R-MLO'],
#   'R-MLO_malignant_seg': ['1192-R-MLO']},
#  '1193': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1193-L-CC'],
#   'L-MLO': ['1193-L-MLO'],
#   'R-CC': ['1193-R-CC'],
#   'R-CC_malignant_seg': ['1193-R-CC'],
#   'R-MLO': ['1193-R-MLO'],
#   'R-MLO_malignant_seg': ['1193-R-MLO']},
#  '1206': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1206-L-CC'],
#   'L-CC_malignant_seg': ['1206-L-CC'],
#   'L-MLO': ['1206-L-MLO'],
#   'L-MLO_malignant_seg': ['1206-L-MLO'],
#   'R-CC': ['1206-R-CC'],
#   'R-MLO': ['1206-R-MLO']},
#  '1221': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1221-L-CC'],
#   'L-CC_malignant_seg': ['1221-L-CC'],
#   'L-MLO': ['1221-L-MLO'],
#   'L-MLO_malignant_seg': ['1221-L-MLO'],
#   'R-CC': ['1221-R-CC'],
#   'R-MLO': ['1221-R-MLO']},
#  '1235': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1235-L-CC'],
#   'L-CC_malignant_seg': ['1235-L-CC'],
#   'L-MLO': ['1235-L-MLO'],
#   'L-MLO_malignant_seg': ['1235-L-MLO'],
#   'R-CC': ['1235-R-CC'],
#   'R-MLO': ['1235-R-MLO']},
#  '1243': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1243-L-CC'],
#   'L-CC_malignant_seg': ['1243-L-CC'],
#   'L-MLO': ['1243-L-MLO'],
#   'L-MLO_malignant_seg': ['1243-L-MLO'],
#   'R-CC': ['1243-R-CC'],
#   'R-MLO': ['1243-R-MLO']},
#  '1264': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1264-L-CC'],
#   'L-MLO': ['1264-L-MLO'],
#   'R-CC': ['1264-R-CC'],
#   'R-CC_malignant_seg': ['1264-R-CC'],
#   'R-MLO': ['1264-R-MLO'],
#   'R-MLO_malignant_seg': ['1264-R-MLO']},
#  '1287': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1287-L-CC'],
#   'L-CC_malignant_seg': ['1287-L-CC'],
#   'L-MLO': ['1287-L-MLO'],
#   'L-MLO_malignant_seg': ['1287-L-MLO'],
#   'R-CC': ['1287-R-CC'],
#   'R-MLO': ['1287-R-MLO']},
#  '1288': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1288-L-CC'],
#   'L-CC_malignant_seg': ['1288-L-CC'],
#   'L-MLO': ['1288-L-MLO'],
#   'L-MLO_malignant_seg': ['1288-L-MLO'],
#   'R-CC': ['1288-R-CC'],
#   'R-MLO': ['1288-R-MLO']},
#  '1299': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1299-L-CC'],
#   'L-MLO': ['1299-L-MLO'],
#   'R-CC': ['1299-R-CC'],
#   'R-CC_malignant_seg': ['1299-R-CC'],
#   'R-MLO': ['1299-R-MLO'],
#   'R-MLO_malignant_seg': ['1299-R-MLO']},
#  '1310': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1310-L-CC'],
#   'L-CC_malignant_seg': ['1310-L-CC'],
#   'L-MLO': ['1310-L-MLO'],
#   'L-MLO_malignant_seg': ['1310-L-MLO'],
#   'R-CC': ['1310-R-CC'],
#   'R-MLO': ['1310-R-MLO']},
#  '1315': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1315-L-CC'],
#   'L-MLO': ['1315-L-MLO'],
#   'R-CC': ['1315-R-CC'],
#   'R-CC_malignant_seg': ['1315-R-CC'],
#   'R-MLO': ['1315-R-MLO'],
#   'R-MLO_malignant_seg': ['1315-R-MLO']},
#  '1328': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1328-L-CC'],
#   'L-MLO': ['1328-L-MLO'],
#   'L-MLO_malignant_seg': ['1328-L-MLO'],
#   'R-CC': ['1328-R-CC'],
#   'R-MLO': ['1328-R-MLO']},
#  '1360': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1360-L-CC'],
#   'L-MLO': ['1360-L-MLO'],
#   'R-CC': ['1360-R-CC'],
#   'R-CC_malignant_seg': ['1360-R-CC'],
#   'R-MLO': ['1360-R-MLO'],
#   'R-MLO_malignant_seg': ['1360-R-MLO']},
#  '1362': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1362-L-CC'],
#   'L-CC_malignant_seg': ['1362-L-CC'],
#   'L-MLO': ['1362-L-MLO'],
#   'L-MLO_malignant_seg': ['1362-L-MLO'],
#   'R-CC': ['1362-R-CC'],
#   'R-MLO': ['1362-R-MLO']},
#  '1363': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1363-L-CC'],
#   'L-MLO': ['1363-L-MLO'],
#   'R-CC': ['1363-R-CC'],
#   'R-CC_malignant_seg': ['1363-R-CC'],
#   'R-MLO': ['1363-R-MLO'],
#   'R-MLO_malignant_seg': ['1363-R-MLO']},
#  '1366': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1366-L-CC'],
#   'L-MLO': ['1366-L-MLO'],
#   'R-CC': ['1366-R-CC'],
#   'R-CC_malignant_seg': ['1366-R-CC'],
#   'R-MLO': ['1366-R-MLO'],
#   'R-MLO_malignant_seg': ['1366-R-MLO']},
#  '1367': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1367-L-CC'],
#   'L-MLO': ['1367-L-MLO'],
#   'R-CC': ['1367-R-CC'],
#   'R-CC_malignant_seg': ['1367-R-CC'],
#   'R-MLO': ['1367-R-MLO'],
#   'R-MLO_malignant_seg': ['1367-R-MLO']},
#  '1401': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1401-L-CC'],
#   'L-MLO': ['1401-L-MLO'],
#   'R-CC': ['1401-R-CC'],
#   'R-CC_malignant_seg': ['1401-R-CC'],
#   'R-MLO': ['1401-R-MLO'],
#   'R-MLO_malignant_seg': ['1401-R-MLO']},
#  '1411': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1411-L-CC'],
#   'L-MLO': ['1411-L-MLO'],
#   'R-CC': ['1411-R-CC'],
#   'R-MLO': ['1411-R-MLO']},
#  '1414': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1414-L-CC'],
#   'L-CC_malignant_seg': ['1414-L-CC'],
#   'L-MLO': ['1414-L-MLO'],
#   'L-MLO_malignant_seg': ['1414-L-MLO'],
#   'R-CC': ['1414-R-CC'],
#   'R-MLO': ['1414-R-MLO']},
#  '1428': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1428-L-CC'],
#   'L-MLO': ['1428-L-MLO'],
#   'R-CC': ['1428-R-CC'],
#   'R-CC_malignant_seg': ['1428-R-CC'],
#   'R-MLO': ['1428-R-MLO'],
#   'R-MLO_malignant_seg': ['1428-R-MLO']},
#  '1434': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1434-L-CC'],
#   'L-MLO': ['1434-L-MLO'],
#   'R-CC': ['1434-R-CC'],
#   'R-MLO': ['1434-R-MLO']},
#  '1456': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1456-L-CC'],
#   'L-CC_malignant_seg': ['1456-L-CC'],
#   'L-MLO': ['1456-L-MLO'],
#   'L-MLO_malignant_seg': ['1456-L-MLO'],
#   'R-CC': ['1456-R-CC'],
#   'R-MLO': ['1456-R-MLO']},
#  '1489': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'R-CC': ['1489-R-CC']},
#  '1505': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1505-L-CC'],
#   'L-CC_malignant_seg': ['1505-L-CC'],
#   'L-MLO': ['1505-L-MLO'],
#   'L-MLO_malignant_seg': ['1505-L-MLO'],
#   'R-CC': ['1505-R-CC'],
#   'R-MLO': ['1505-R-MLO']},
#  '1506': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1506-L-CC'],
#   'L-MLO': ['1506-L-MLO'],
#   'L-MLO_malignant_seg': ['1506-L-MLO'],
#   'R-CC': ['1506-R-CC'],
#   'R-MLO': ['1506-R-MLO']},
#  '1516': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1516-L-CC'],
#   'L-MLO': ['1516-L-MLO'],
#   'R-CC': ['1516-R-CC'],
#   'R-CC_malignant_seg': ['1516-R-CC'],
#   'R-MLO': ['1516-R-MLO'],
#   'R-MLO_malignant_seg': ['1516-R-MLO']},
#  '1524': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1524-L-CC'],
#   'L-MLO': ['1524-L-MLO'],
#   'R-CC': ['1524-R-CC'],
#   'R-CC_malignant_seg': ['1524-R-CC'],
#   'R-MLO': ['1524-R-MLO'],
#   'R-MLO_malignant_seg': ['1524-R-MLO']},
#  '1525': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1525-L-CC'],
#   'L-CC_malignant_seg': ['1525-L-CC'],
#   'L-MLO': ['1525-L-MLO'],
#   'L-MLO_malignant_seg': ['1525-L-MLO'],
#   'R-CC': ['1525-R-CC'],
#   'R-MLO': ['1525-R-MLO']},
#  'PBCP_0181_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['PBCP_0181_T-L-CC'],
#   'L-CC_malignant_seg': ['PBCP_0181_T-L-CC'],
#   'L-MLO': ['PBCP_0181_T-L-MLO'],
#   'L-MLO_malignant_seg': ['PBCP_0181_T-L-MLO'],
#   'R-CC': ['PBCP_0181_T-R-CC'],
#   'R-MLO': ['PBCP_0181_T-R-MLO']},
#  'PBCP_0219_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0219_T-L-CC'],
#   'L-MLO': ['PBCP_0219_T-L-MLO'],
#   'R-CC': ['PBCP_0219_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0219_T-R-CC'],
#   'R-MLO': ['PBCP_0219_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0219_T-R-MLO']},
#  'PBCP_0222_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['PBCP_0222_T-L-CC'],
#   'L-CC_malignant_seg': ['PBCP_0222_T-L-CC'],
#   'L-MLO': ['PBCP_0222_T-L-MLO'],
#   'L-MLO_malignant_seg': ['PBCP_0222_T-L-MLO'],
#   'R-CC': ['PBCP_0222_T-R-CC'],
#   'R-MLO': ['PBCP_0222_T-R-MLO']},
#  'PBCP_0223_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'R-CC': ['PBCP_0223_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0223_T-R-CC'],
#   'R-MLO': ['PBCP_0223_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0223_T-R-MLO']},
#  'PBCP_0238_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0238_T-L-CC'],
#   'L-MLO': ['PBCP_0238_T-L-MLO'],
#   'R-CC': ['PBCP_0238_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0238_T-R-CC'],
#   'R-MLO': ['PBCP_0238_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0238_T-R-MLO']},
#  'PBCP_0250_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['PBCP_0250_T-L-CC'],
#   'L-CC_malignant_seg': ['PBCP_0250_T-L-CC'],
#   'L-MLO': ['PBCP_0250_T-L-MLO'],
#   'L-MLO_malignant_seg': ['PBCP_0250_T-L-MLO'],
#   'R-CC': ['PBCP_0250_T-R-CC'],
#   'R-MLO': ['PBCP_0250_T-R-MLO']},
#  'PBCP_0311_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0311_T-L-CC'],
#   'L-MLO': ['PBCP_0311_T-L-MLO'],
#   'R-CC': ['PBCP_0311_T-R-CC'],
#   'R-MLO': ['PBCP_0311_T-R-MLO']},
#  'PBCP_0327_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0327_T-L-CC'],
#   'L-MLO': ['PBCP_0327_T-L-MLO'],
#   'R-CC': ['PBCP_0327_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0327_T-R-CC'],
#   'R-MLO': ['PBCP_0327_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0327_T-R-MLO']},
#  'PBCP_0341_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0341_T-L-CC'],
#   'L-MLO': ['PBCP_0341_T-L-MLO'],
#   'R-CC': ['PBCP_0341_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0341_T-R-CC'],
#   'R-MLO': ['PBCP_0341_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0341_T-R-MLO']},
#  'PBCP_0420_T_R': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0420_T_R-L-CC'],
#   'L-MLO': ['PBCP_0420_T_R-L-MLO'],
#   'R-CC': ['PBCP_0420_T_R-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0420_T_R-R-CC'],
#   'R-MLO': ['PBCP_0420_T_R-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0420_T_R-R-MLO']},
#  'PBCP_0492_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['PBCP_0492_T-L-CC'],
#   'L-CC_malignant_seg': ['PBCP_0492_T-L-CC'],
#   'L-MLO': ['PBCP_0492_T-L-MLO'],
#   'L-MLO_malignant_seg': ['PBCP_0492_T-L-MLO'],
#   'R-CC': ['PBCP_0492_T-R-CC'],
#   'R-MLO': ['PBCP_0492_T-R-MLO']},
#  'PBCP_0604_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0604_T-L-CC'],
#   'L-MLO': ['PBCP_0604_T-L-MLO'],
#   'R-CC': ['PBCP_0604_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0604_T-R-CC'],
#   'R-MLO': ['PBCP_0604_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0604_T-R-MLO']},
#  'PBCP_0656_T': {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['PBCP_0656_T-L-CC'],
#   'L-CC_malignant_seg': ['PBCP_0656_T-L-CC'],
#   'L-MLO': ['PBCP_0656_T-L-MLO'],
#   'L-MLO_malignant_seg': ['PBCP_0656_T-L-MLO'],
#   'R-CC': ['PBCP_0656_T-R-CC'],
#   'R-MLO': ['PBCP_0656_T-R-MLO']}}

# %%
_list = [j for i, j in _dict.items()]
os.makedirs('/local/scratch-2/gp518/preprocessed_data/PARTNER_GLAM', exist_ok=True)
with open('/local/scratch-2/gp518/preprocessed_data/PARTNER_GLAM/exam_list_before_cropping.pkl', 'wb') as handle:
    pickle.dump(_list, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/local/scratch-2/gp518/preprocessed_data/PARTNER/exam_list_before_cropping.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
# [{'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1179-L-CC'],
#   'L-CC_malignant_seg': ['1179-L-CC'],
#   'L-MLO': ['1179-L-MLO'],
#   'L-MLO_malignant_seg': ['1179-L-MLO'],
#   'R-CC': ['1179-R-CC'],
#   'R-MLO': ['1179-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1150-L-CC'],
#   'L-MLO': ['1150-L-MLO'],
#   'R-CC': ['1150-R-CC'],
#   'R-MLO': ['1150-R-MLO'],
#   'R-MLO_malignant_seg': ['1150-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0604_T-L-CC'],
#   'L-MLO': ['PBCP_0604_T-L-MLO'],
#   'R-CC': ['PBCP_0604_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0604_T-R-CC'],
#   'R-MLO': ['PBCP_0604_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0604_T-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1024-L-CC'],
#   'L-MLO': ['1024-L-MLO'],
#   'R-CC': ['1024-R-CC'],
#   'R-CC_malignant_seg': ['1024-R-CC'],
#   'R-MLO': ['1024-R-MLO'],
#   'R-MLO_malignant_seg': ['1024-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1057-L-CC'],
#   'L-MLO': ['1057-L-MLO'],
#   'R-CC': ['1057-R-CC'],
#   'R-CC_malignant_seg': ['1057-R-CC'],
#   'R-MLO': ['1057-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-MLO': ['1165-L-MLO'],
#   'L-MLO_malignant_seg': ['1165-L-MLO'],
#   'R-CC': ['1165-R-CC'],
#   'R-MLO': ['1165-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1103-L-CC'],
#   'L-MLO': ['1103-L-MLO'],
#   'R-CC': ['1103-R-CC'],
#   'R-MLO': ['1103-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1181-L-CC'],
#   'L-MLO': ['1181-L-MLO'],
#   'R-CC': ['1181-R-CC'],
#   'R-CC_malignant_seg': ['1181-R-CC'],
#   'R-MLO': ['1181-R-MLO'],
#   'R-MLO_malignant_seg': ['1181-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1093-L-CC'],
#   'L-MLO': ['1093-L-MLO'],
#   'R-CC': ['1093-R-CC'],
#   'R-CC_malignant_seg': ['1093-R-CC'],
#   'R-MLO': ['1093-R-MLO'],
#   'R-MLO_malignant_seg': ['1093-R-MLO']},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1145-L-CC'],
#   'L-MLO': ['1145-L-MLO'],
#   'R-CC': ['1145-R-CC'],
#   'R-MLO': ['1145-R-MLO']}]

# %%
with open('/home/gp518/projects/GLAM/sample_data/exam_list_before_cropping.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
# [{'horizontal_flip': 'NO',
#   'L-CC': ['0_L-CC'],
#   'L-MLO': ['0_L-MLO'],
#   'R-MLO': ['0_R-MLO'],
#   'R-CC': ['0_R-CC'],
#   'cancer_label': {'benign': 1,
#    'right_benign': 1,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC_benign_seg': ['0_L-CC_benign'],
#   'L-CC_malignant_seg': ['0_L-CC_malignant'],
#   'L-MLO_benign_seg': ['0_L-MLO_benign'],
#   'L-MLO_malignant_seg': ['0_L-MLO_malignant'],
#   'R-MLO_benign_seg': ['0_R-MLO_benign'],
#   'R-MLO_malignant_seg': ['0_R-MLO_malignant'],
#   'R-CC_benign_seg': ['0_R-CC_benign'],
#   'R-CC_malignant_seg': ['0_R-CC_malignant']},
#  {'horizontal_flip': 'NO',
#   'L-CC': ['1_L-CC'],
#   'L-MLO': ['1_L-MLO'],
#   'R-MLO': ['1_R-MLO'],
#   'R-CC': ['1_R-CC'],
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC_benign_seg': ['1_L-CC_benign'],
#   'L-CC_malignant_seg': ['1_L-CC_malignant'],
#   'L-MLO_benign_seg': ['1_L-MLO_benign'],
#   'L-MLO_malignant_seg': ['1_L-MLO_malignant'],
#   'R-MLO_benign_seg': ['1_R-MLO_benign'],
#   'R-MLO_malignant_seg': ['1_R-MLO_malignant'],
#   'R-CC_benign_seg': ['1_R-CC_benign'],
#   'R-CC_malignant_seg': ['1_R-CC_malignant']},
#  {'horizontal_flip': 'NO',
#   'L-CC': ['2_L-CC'],
#   'L-MLO': ['2_L-MLO'],
#   'R-MLO': ['2_R-MLO'],
#   'R-CC': ['2_R-CC'],
#   'cancer_label': {'benign': 1,
#    'right_benign': 1,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC_benign_seg': ['2_L-CC_benign'],
#   'L-CC_malignant_seg': ['2_L-CC_malignant'],
#   'L-MLO_benign_seg': ['2_L-MLO_benign'],
#   'L-MLO_malignant_seg': ['2_L-MLO_malignant'],
#   'R-MLO_benign_seg': ['2_R-MLO_benign'],
#   'R-MLO_malignant_seg': ['2_R-MLO_malignant'],
#   'R-CC_benign_seg': ['2_R-CC_benign'],
#   'R-CC_malignant_seg': ['2_R-CC_malignant']},
#  {'horizontal_flip': 'NO',
#   'L-CC': ['3_L-CC'],
#   'L-MLO': ['3_L-MLO'],
#   'R-MLO': ['3_R-MLO'],
#   'R-CC': ['3_R-CC'],
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC_benign_seg': ['3_L-CC_benign'],
#   'L-CC_malignant_seg': ['3_L-CC_malignant'],
#   'L-MLO_benign_seg': ['3_L-MLO_benign'],
#   'L-MLO_malignant_seg': ['3_L-MLO_malignant'],
#   'R-MLO_benign_seg': ['3_R-MLO_benign'],
#   'R-MLO_malignant_seg': ['3_R-MLO_malignant'],
#   'R-CC_benign_seg': ['3_R-CC_benign'],
#   'R-CC_malignant_seg': ['3_R-CC_malignant']}]

# %%
with open('/local/scratch-2/gp518/preprocessed_data/PARTNER_cropped/exam_list_after_cropping.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
# [{'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1179-L-CC'],
#   'L-CC_malignant_seg': ['1179-L-CC'],
#   'L-MLO': ['1179-L-MLO'],
#   'L-MLO_malignant_seg': ['1179-L-MLO'],
#   'R-CC': ['1179-R-CC'],
#   'R-MLO': ['1179-R-MLO'],
#   'window_location': {'L-CC': [(637, 4901, 0, 2850)],
#    'R-CC': [(361, 4651, 2090, 4915)],
#    'L-MLO': [(0, 4208, 0, 3338)],
#    'R-MLO': [(0, 3964, 1638, 4915)]},
#   'rightmost_points': {'L-CC': [((2302, 2345), 2799)],
#    'R-CC': [((1909, 2513), 2775)],
#    'L-MLO': [((2325, 2378), 3287)],
#    'R-MLO': [((2134, 2166), 3227)]},
#   'bottommost_points': {'L-CC': [(4213, (100, 102))],
#    'R-CC': [(4239, (346, 468))],
#    'L-MLO': [(4157, (100, 100))],
#    'R-MLO': [(3913, (1611, 1650))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1150-L-CC'],
#   'L-MLO': ['1150-L-MLO'],
#   'R-CC': ['1150-R-CC'],
#   'R-MLO': ['1150-R-MLO'],
#   'R-MLO_malignant_seg': ['1150-R-MLO'],
#   'window_location': {'L-CC': [(209, 2079, 0, 879)],
#    'R-CC': [(208, 2026, 981, 1914)],
#    'L-MLO': [(0, 1910, 0, 1047)],
#    'R-MLO': [(0, 1943, 840, 1914)]},
#   'rightmost_points': {'L-CC': [((936, 954), 828)],
#    'R-CC': [((880, 890), 883)],
#    'L-MLO': [((1032, 1059), 996)],
#    'R-MLO': [((1096, 1112), 1024)]},
#   'bottommost_points': {'L-CC': [(1819, (100, 123))],
#    'R-CC': [(1767, (122, 255))],
#    'L-MLO': [(1859, (374, 444))],
#    'R-MLO': [(1892, (428, 503))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0604_T-L-CC'],
#   'L-MLO': ['PBCP_0604_T-L-MLO'],
#   'R-CC': ['PBCP_0604_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0604_T-R-CC'],
#   'R-MLO': ['PBCP_0604_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0604_T-R-MLO'],
#   'window_location': {'L-CC': [(133, 5355, 0, 2648)],
#    'R-CC': [(2, 5355, 1572, 4915)],
#    'L-MLO': [(0, 4908, 0, 2955)],
#    'R-MLO': [(0, 5273, 1415, 4915)]},
#   'rightmost_points': {'L-CC': [((2587, 2653), 2597)],
#    'R-CC': [((2399, 2429), 3293)],
#    'L-MLO': [((2935, 2982), 2904)],
#    'R-MLO': [((3454, 3474), 3450)]},
#   'bottommost_points': {'L-CC': [(5221, (100, 271))],
#    'R-CC': [(5352, (101, 651))],
#    'L-MLO': [(4857, (1039, 1144))],
#    'R-MLO': [(5222, (1301, 1351))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1024-L-CC'],
#   'L-MLO': ['1024-L-MLO'],
#   'R-CC': ['1024-R-CC'],
#   'R-CC_malignant_seg': ['1024-R-CC'],
#   'R-MLO': ['1024-R-MLO'],
#   'R-MLO_malignant_seg': ['1024-R-MLO'],
#   'window_location': {'L-CC': [(651, 2673, 0, 1066)],
#    'R-CC': [(609, 2479, 1390, 2394)],
#    'L-MLO': [(0, 2236, 0, 1086)],
#    'R-MLO': [(0, 2106, 1332, 2394)]},
#   'rightmost_points': {'L-CC': [((988, 1013), 1015)],
#    'R-CC': [((830, 845), 954)],
#    'L-MLO': [((1411, 1435), 1035)],
#    'R-MLO': [((1203, 1260), 1012)]},
#   'bottommost_points': {'L-CC': [(1971, (145, 235))],
#    'R-CC': [(1819, (189, 221))],
#    'L-MLO': [(2185, (100, 100))],
#    'R-MLO': [(2055, (101, 101))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1057-L-CC'],
#   'L-MLO': ['1057-L-MLO'],
#   'R-CC': ['1057-R-CC'],
#   'R-CC_malignant_seg': ['1057-R-CC'],
#   'R-MLO': ['1057-R-MLO'],
#   'window_location': {'L-CC': [(869, 4434, 0, 1626)],
#    'R-CC': [(461, 4067, 3398, 4915)],
#    'L-MLO': [(0, 4468, 0, 1777)],
#    'R-MLO': [(0, 4279, 3024, 4915)]},
#   'rightmost_points': {'L-CC': [((2005, 2006), 1575)],
#    'R-CC': [((1809, 1809), 1467)],
#    'L-MLO': [((3008, 3008), 1726)],
#    'R-MLO': [((2783, 2791), 1841)]},
#   'bottommost_points': {'L-CC': [(3514, (273, 273))],
#    'R-CC': [(3555, (117, 119))],
#    'L-MLO': [(4417, (329, 330))],
#    'R-MLO': [(4228, (101, 101))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-MLO': ['1165-L-MLO'],
#   'L-MLO_malignant_seg': ['1165-L-MLO'],
#   'R-CC': ['1165-R-CC'],
#   'R-MLO': ['1165-R-MLO'],
#   'window_location': {'R-CC': [(220, 1960, 1218, 1914)],
#    'L-MLO': [(0, 2207, 0, 878)],
#    'R-MLO': [(0, 2091, 1085, 1914)]},
#   'rightmost_points': {'R-CC': [((930, 941), 646)],
#    'L-MLO': [((1411, 1419), 827)],
#    'R-MLO': [((1266, 1309), 779)]},
#   'bottommost_points': {'R-CC': [(1689, (101, 101))],
#    'L-MLO': [(2156, (100, 100))],
#    'R-MLO': [(2040, (101, 101))]},
#   'distance_from_starting_side': {'R-CC': [0], 'L-MLO': [0], 'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1103-L-CC'],
#   'L-MLO': ['1103-L-MLO'],
#   'R-CC': ['1103-R-CC'],
#   'R-MLO': ['1103-R-MLO'],
#   'window_location': {'L-CC': [(483, 2239, 0, 920)],
#    'R-CC': [(186, 2072, 1015, 1914)],
#    'L-MLO': [(0, 1928, 0, 988)],
#    'R-MLO': [(0, 1871, 921, 1914)]},
#   'rightmost_points': {'L-CC': [((1002, 1056), 869)],
#    'R-CC': [((943, 959), 849)],
#    'L-MLO': [((1118, 1129), 937)],
#    'R-MLO': [((1026, 1116), 943)]},
#   'bottommost_points': {'L-CC': [(1705, (100, 112))],
#    'R-CC': [(1835, (101, 108))],
#    'L-MLO': [(1877, (219, 248))],
#    'R-MLO': [(1820, (231, 247))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1181-L-CC'],
#   'L-MLO': ['1181-L-MLO'],
#   'R-CC': ['1181-R-CC'],
#   'R-CC_malignant_seg': ['1181-R-CC'],
#   'R-MLO': ['1181-R-MLO'],
#   'R-MLO_malignant_seg': ['1181-R-MLO'],
#   'window_location': {'L-CC': [(1010, 4127, 0, 1387)],
#    'R-CC': [(1127, 4035, 3481, 4915)],
#    'L-MLO': [(0, 4201, 0, 1484)],
#    'R-MLO': [(0, 4739, 3483, 4915)]},
#   'rightmost_points': {'L-CC': [((1785, 1799), 1336)],
#    'R-CC': [((1482, 1488), 1384)],
#    'L-MLO': [((2694, 2701), 1433)],
#    'R-MLO': [((3380, 3400), 1382)]},
#   'bottommost_points': {'L-CC': [(3066, (100, 100))],
#    'R-CC': [(2857, (101, 101))],
#    'L-MLO': [(4150, (100, 100))],
#    'R-MLO': [(4688, (101, 101))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1093-L-CC'],
#   'L-MLO': ['1093-L-MLO'],
#   'R-CC': ['1093-R-CC'],
#   'R-CC_malignant_seg': ['1093-R-CC'],
#   'R-MLO': ['1093-R-MLO'],
#   'R-MLO_malignant_seg': ['1093-R-MLO'],
#   'window_location': {'L-CC': [(38, 2163, 0, 1179)],
#    'R-CC': [(47, 2272, 750, 1914)],
#    'L-MLO': [(0, 2168, 0, 1165)],
#    'R-MLO': [(0, 2294, 741, 1914)]},
#   'rightmost_points': {'L-CC': [((1110, 1110), 1128)],
#    'R-CC': [((1371, 1377), 1114)],
#    'L-MLO': [((1142, 1256), 1114)],
#    'R-MLO': [((1369, 1401), 1123)]},
#   'bottommost_points': {'L-CC': [(2074, (100, 101))],
#    'R-CC': [(2174, (101, 105))],
#    'L-MLO': [(2117, (100, 104))],
#    'R-MLO': [(2293, (101, 287))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1145-L-CC'],
#   'L-MLO': ['1145-L-MLO'],
#   'R-CC': ['1145-R-CC'],
#   'R-MLO': ['1145-R-MLO'],
#   'window_location': {'L-CC': [(483, 2334, 0, 727)],
#    'R-CC': [(459, 2213, 1752, 2394)],
#    'L-MLO': [(0, 2187, 0, 819)],
#    'R-MLO': [(0, 2427, 1764, 2394)]},
#   'rightmost_points': {'L-CC': [((844, 845), 676)],
#    'R-CC': [((730, 731), 592)],
#    'L-MLO': [((1045, 1185), 768)],
#    'R-MLO': [((1351, 1514), 560)]},
#   'bottommost_points': {'L-CC': [(1800, (100, 100))],
#    'R-CC': [(1703, (101, 102))],
#    'L-MLO': [(2136, (100, 103))],
#    'R-MLO': [(2376, (101, 102))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]}}]

# %%
with open('/local/scratch-2/gp518/preprocessed_data/PARTNER_cropped/exam_list_final.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
# [{'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-CC': ['1179-L-CC'],
#   'L-CC_malignant_seg': ['1179-L-CC'],
#   'L-MLO': ['1179-L-MLO'],
#   'L-MLO_malignant_seg': ['1179-L-MLO'],
#   'R-CC': ['1179-R-CC'],
#   'R-MLO': ['1179-R-MLO'],
#   'window_location': {'L-CC': [(637, 4901, 0, 2850)],
#    'R-CC': [(361, 4651, 2090, 4915)],
#    'L-MLO': [(0, 4208, 0, 3338)],
#    'R-MLO': [(0, 3964, 1638, 4915)]},
#   'rightmost_points': {'L-CC': [((2302, 2345), 2799)],
#    'R-CC': [((1909, 2513), 2775)],
#    'L-MLO': [((2325, 2378), 3287)],
#    'R-MLO': [((2134, 2166), 3227)]},
#   'bottommost_points': {'L-CC': [(4213, (100, 102))],
#    'R-CC': [(4239, (346, 468))],
#    'L-MLO': [(4157, (100, 100))],
#    'R-MLO': [(3913, (1611, 1650))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(2342, 1838)],
#    'R-CC': [(2362, 1814)],
#    'L-MLO': [(2600, 2326)],
#    'R-MLO': [(2440, 2266)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1150-L-CC'],
#   'L-MLO': ['1150-L-MLO'],
#   'R-CC': ['1150-R-CC'],
#   'R-MLO': ['1150-R-MLO'],
#   'R-MLO_malignant_seg': ['1150-R-MLO'],
#   'window_location': {'L-CC': [(209, 2079, 0, 879)],
#    'R-CC': [(208, 2026, 981, 1914)],
#    'L-MLO': [(0, 1910, 0, 1047)],
#    'R-MLO': [(0, 1943, 840, 1914)]},
#   'rightmost_points': {'L-CC': [((936, 954), 828)],
#    'R-CC': [((880, 890), 883)],
#    'L-MLO': [((1032, 1059), 996)],
#    'R-MLO': [((1096, 1112), 1024)]},
#   'bottommost_points': {'L-CC': [(1819, (100, 123))],
#    'R-CC': [(1767, (122, 255))],
#    'L-MLO': [(1859, (374, 444))],
#    'R-MLO': [(1892, (428, 503))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(935, -133)],
#    'R-CC': [(909, -78)],
#    'L-MLO': [(386, 35)],
#    'R-MLO': [(419, 63)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['PBCP_0604_T-L-CC'],
#   'L-MLO': ['PBCP_0604_T-L-MLO'],
#   'R-CC': ['PBCP_0604_T-R-CC'],
#   'R-CC_malignant_seg': ['PBCP_0604_T-R-CC'],
#   'R-MLO': ['PBCP_0604_T-R-MLO'],
#   'R-MLO_malignant_seg': ['PBCP_0604_T-R-MLO'],
#   'window_location': {'L-CC': [(133, 5355, 0, 2648)],
#    'R-CC': [(2, 5355, 1572, 4915)],
#    'L-MLO': [(0, 4908, 0, 2955)],
#    'R-MLO': [(0, 5273, 1415, 4915)]},
#   'rightmost_points': {'L-CC': [((2587, 2653), 2597)],
#    'R-CC': [((2399, 2429), 3293)],
#    'L-MLO': [((2935, 2982), 2904)],
#    'R-MLO': [((3454, 3474), 3450)]},
#   'bottommost_points': {'L-CC': [(5221, (100, 271))],
#    'R-CC': [(5352, (101, 651))],
#    'L-MLO': [(4857, (1039, 1144))],
#    'R-MLO': [(5222, (1301, 1351))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(2592, 1636)],
#    'R-CC': [(2777, 2332)],
#    'L-MLO': [(3384, 1943)],
#    'R-MLO': [(3741, 2489)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1024-L-CC'],
#   'L-MLO': ['1024-L-MLO'],
#   'R-CC': ['1024-R-CC'],
#   'R-CC_malignant_seg': ['1024-R-CC'],
#   'R-MLO': ['1024-R-MLO'],
#   'R-MLO_malignant_seg': ['1024-R-MLO'],
#   'window_location': {'L-CC': [(651, 2673, 0, 1066)],
#    'R-CC': [(609, 2479, 1390, 2394)],
#    'L-MLO': [(0, 2236, 0, 1086)],
#    'R-MLO': [(0, 2106, 1332, 2394)]},
#   'rightmost_points': {'L-CC': [((988, 1013), 1015)],
#    'R-CC': [((830, 845), 954)],
#    'L-MLO': [((1411, 1435), 1035)],
#    'R-MLO': [((1203, 1260), 1012)]},
#   'bottommost_points': {'L-CC': [(1971, (145, 235))],
#    'R-CC': [(1819, (189, 221))],
#    'L-MLO': [(2185, (100, 100))],
#    'R-MLO': [(2055, (101, 101))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(1011, 54)],
#    'R-CC': [(935, -7)],
#    'L-MLO': [(712, 74)],
#    'R-MLO': [(582, 51)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1057-L-CC'],
#   'L-MLO': ['1057-L-MLO'],
#   'R-CC': ['1057-R-CC'],
#   'R-CC_malignant_seg': ['1057-R-CC'],
#   'R-MLO': ['1057-R-MLO'],
#   'window_location': {'L-CC': [(869, 4434, 0, 1626)],
#    'R-CC': [(461, 4067, 3398, 4915)],
#    'L-MLO': [(0, 4468, 0, 1777)],
#    'R-MLO': [(0, 4279, 3024, 4915)]},
#   'rightmost_points': {'L-CC': [((2005, 2006), 1575)],
#    'R-CC': [((1809, 1809), 1467)],
#    'L-MLO': [((3008, 3008), 1726)],
#    'R-MLO': [((2783, 2791), 1841)]},
#   'bottommost_points': {'L-CC': [(3514, (273, 273))],
#    'R-CC': [(3555, (117, 119))],
#    'L-MLO': [(4417, (329, 330))],
#    'R-MLO': [(4228, (101, 101))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(1873, 614)],
#    'R-CC': [(1912, 506)],
#    'L-MLO': [(2944, 765)],
#    'R-MLO': [(2755, 880)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 1},
#   'L-MLO': ['1165-L-MLO'],
#   'L-MLO_malignant_seg': ['1165-L-MLO'],
#   'R-CC': ['1165-R-CC'],
#   'R-MLO': ['1165-R-MLO'],
#   'window_location': {'R-CC': [(220, 1960, 1218, 1914)],
#    'L-MLO': [(0, 2207, 0, 878)],
#    'R-MLO': [(0, 2091, 1085, 1914)]},
#   'rightmost_points': {'R-CC': [((930, 941), 646)],
#    'L-MLO': [((1411, 1419), 827)],
#    'R-MLO': [((1266, 1309), 779)]},
#   'bottommost_points': {'R-CC': [(1689, (101, 101))],
#    'L-MLO': [(2156, (100, 100))],
#    'R-MLO': [(2040, (101, 101))]},
#   'distance_from_starting_side': {'R-CC': [0], 'L-MLO': [0], 'R-MLO': [0]},
#   'best_center': {'R-CC': [(870, -315)],
#    'L-MLO': [(683, -134)],
#    'R-MLO': [(567, -182)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1103-L-CC'],
#   'L-MLO': ['1103-L-MLO'],
#   'R-CC': ['1103-R-CC'],
#   'R-MLO': ['1103-R-MLO'],
#   'window_location': {'L-CC': [(483, 2239, 0, 920)],
#    'R-CC': [(186, 2072, 1015, 1914)],
#    'L-MLO': [(0, 1928, 0, 988)],
#    'R-MLO': [(0, 1871, 921, 1914)]},
#   'rightmost_points': {'L-CC': [((1002, 1056), 869)],
#    'R-CC': [((943, 959), 849)],
#    'L-MLO': [((1118, 1129), 937)],
#    'R-MLO': [((1026, 1116), 943)]},
#   'bottommost_points': {'L-CC': [(1705, (100, 112))],
#    'R-CC': [(1835, (101, 108))],
#    'L-MLO': [(1877, (219, 248))],
#    'R-MLO': [(1820, (231, 247))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(878, -92)],
#    'R-CC': [(943, -112)],
#    'L-MLO': [(404, -24)],
#    'R-MLO': [(347, -18)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1181-L-CC'],
#   'L-MLO': ['1181-L-MLO'],
#   'R-CC': ['1181-R-CC'],
#   'R-CC_malignant_seg': ['1181-R-CC'],
#   'R-MLO': ['1181-R-MLO'],
#   'R-MLO_malignant_seg': ['1181-R-MLO'],
#   'window_location': {'L-CC': [(1010, 4127, 0, 1387)],
#    'R-CC': [(1127, 4035, 3481, 4915)],
#    'L-MLO': [(0, 4201, 0, 1484)],
#    'R-MLO': [(0, 4739, 3483, 4915)]},
#   'rightmost_points': {'L-CC': [((1785, 1799), 1336)],
#    'R-CC': [((1482, 1488), 1384)],
#    'L-MLO': [((2694, 2701), 1433)],
#    'R-MLO': [((3380, 3400), 1382)]},
#   'bottommost_points': {'L-CC': [(3066, (100, 100))],
#    'R-CC': [(2857, (101, 101))],
#    'L-MLO': [(4150, (100, 100))],
#    'R-MLO': [(4688, (101, 101))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(1577, 375)],
#    'R-CC': [(1454, 423)],
#    'L-MLO': [(2677, 472)],
#    'R-MLO': [(3215, 421)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 1,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 1,
#    'left_malignant': 0},
#   'L-CC': ['1093-L-CC'],
#   'L-MLO': ['1093-L-MLO'],
#   'R-CC': ['1093-R-CC'],
#   'R-CC_malignant_seg': ['1093-R-CC'],
#   'R-MLO': ['1093-R-MLO'],
#   'R-MLO_malignant_seg': ['1093-R-MLO'],
#   'window_location': {'L-CC': [(38, 2163, 0, 1179)],
#    'R-CC': [(47, 2272, 750, 1914)],
#    'L-MLO': [(0, 2168, 0, 1165)],
#    'R-MLO': [(0, 2294, 741, 1914)]},
#   'rightmost_points': {'L-CC': [((1110, 1110), 1128)],
#    'R-CC': [((1371, 1377), 1114)],
#    'L-MLO': [((1142, 1256), 1114)],
#    'R-MLO': [((1369, 1401), 1123)]},
#   'bottommost_points': {'L-CC': [(2074, (100, 101))],
#    'R-CC': [(2174, (101, 105))],
#    'L-MLO': [(2117, (100, 104))],
#    'R-MLO': [(2293, (101, 287))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(1062, 167)],
#    'R-CC': [(1112, 153)],
#    'L-MLO': [(644, 153)],
#    'R-MLO': [(820, 162)]}},
#  {'horizontal_flip': 'NO',
#   'cancer_label': {'benign': 0,
#    'right_benign': 0,
#    'malignant': 0,
#    'left_benign': 0,
#    'unknown': 0,
#    'right_malignant': 0,
#    'left_malignant': 0},
#   'L-CC': ['1145-L-CC'],
#   'L-MLO': ['1145-L-MLO'],
#   'R-CC': ['1145-R-CC'],
#   'R-MLO': ['1145-R-MLO'],
#   'window_location': {'L-CC': [(483, 2334, 0, 727)],
#    'R-CC': [(459, 2213, 1752, 2394)],
#    'L-MLO': [(0, 2187, 0, 819)],
#    'R-MLO': [(0, 2427, 1764, 2394)]},
#   'rightmost_points': {'L-CC': [((844, 845), 676)],
#    'R-CC': [((730, 731), 592)],
#    'L-MLO': [((1045, 1185), 768)],
#    'R-MLO': [((1351, 1514), 560)]},
#   'bottommost_points': {'L-CC': [(1800, (100, 100))],
#    'R-CC': [(1703, (101, 102))],
#    'L-MLO': [(2136, (100, 103))],
#    'R-MLO': [(2376, (101, 102))]},
#   'distance_from_starting_side': {'L-CC': [0],
#    'R-CC': [0],
#    'L-MLO': [0],
#    'R-MLO': [0]},
#   'best_center': {'L-CC': [(925, -285)],
#    'R-CC': [(877, -369)],
#    'L-MLO': [(663, -193)],
#    'R-MLO': [(903, -401)]}}]
